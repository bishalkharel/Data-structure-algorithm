# %% [markdown]
# ## The  Queues - Queues Basic
#
# ### What is queues?
# <b>Ans: So queues are sds which follows the FIFO (First In First Out) principal </b>

# %% [markdown]
# ### Visualize the Queues
# ![Screenshot_2021-07-20-14-32-53-137_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-14-32-53-137_com.google.android.youtube.jpg)

# %% [markdown]
# ### Methods of queues:
# - Enqueue
# - Dequeue
# - Peek
# - Contains

# %% [markdown]
# - <b>Enqueue:
#     It adds object in tail which is the entering point of queue
#     ![Screenshot_2021-07-20-14-43-24-746_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-14-43-24-746_com.google.android.youtube.jpg)
# - Dequeue: It removes the objects from head which is the ending point of queues. It takes no argument and removes the element at head. In above example if we apply it will remove "now" object.<br><br>
# - Peek: It helps us to access the element from head part which is the ending part of queues. It also takes no argument and gives the element at fore most i.e head.<br><br>
# - Contains: It searches the element in queues. It return the boolean value if the given object is in queue then it will return True else it will return False

# %% [markdown]
# <font color="green" size="6px"> Time complexity for Queues</font>
#
# ![Screenshot_2021-07-20-15-46-09-113_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-15-46-09-113_com.google.android.youtube.jpg)

# %% [markdown]
# <font color="blue" size="6px">Conclusion for queues</font>
#
#
# ![Screenshot_2021-07-20-15-50-40-114_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-15-50-40-114_com.google.android.youtube.jpg)
