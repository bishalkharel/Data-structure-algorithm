# %% [markdown]
# <br>
# <b><font color="black" size="7px">Linked List</font></b><br>

# %% [markdown]
# <br><font color="purple" size="4px">
#     <ul type="disc">
#     <li> What is linked list?</li>
#     <li>What are its usage?</li>

# %% [markdown]
# ![Screenshot_2021-07-20-16-02-50-295_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-16-02-50-295_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-20-16-12-49-815_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-16-12-49-815_com.google.android.youtube.jpg)

# %% [markdown]
# ### This picture tells us whats behind all these
# ![Screenshot_2021-07-20-16-14-27-713_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-16-14-27-713_com.google.android.youtube.jpg)

# %% [markdown]
# <b><p> We saw that each node contains two parts ( data, pointer) lets visualize it

# %% [markdown]
# ![Screenshot_2021-07-20-16-25-54-732_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-16-25-54-732_com.google.android.youtube.jpg)

# %% [markdown]
# <b>The last nodes pointer will always point towards null because there are no any nodes further that. Suppose if there was a single node in above pic then its pointer value would be null</b>

# %% [markdown]
# ### Adding and removing information in linked list

# %% [markdown]
# - <b> Adding a new head node
# ![Screenshot_2021-07-20-16-39-32-388_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-16-39-32-388_com.google.android.youtube.jpg)
# <br>
# <b> To add a new head node in linked list you just point towards the current head node as shown in above figure

# %% [markdown]
# <b> We dont have any name of methods in linked list we do have some techniques to play around with nodes</b>
# - <font color="green"><b> To remove a node from linked list</b></font>
# We basically point its pointing value to null value and it gets disconnected from linked list
# -<font color="green"><b>To insert a node in between two nodes in linked list</b></font> we basically point back node pointer to  inserting nodes pointer and inseting pointer points towards front node pointer
# ![Screenshot_2021-07-20-20-29-10-773_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-20-20-29-10-773_com.google.android.youtube.jpg)
