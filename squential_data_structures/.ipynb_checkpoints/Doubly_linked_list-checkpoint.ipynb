# %% [markdown]
# ## Doubly linked list

# %% [markdown]
# The doubly linked list is there to mitigate the problems of linked list (cannot go backward node). See the following figure and understand

# %% [markdown]
# ![Screenshot_2021-07-22-17-25-30-881_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-22-17-25-30-881_com.google.android.youtube.jpg)

# %% [markdown]
# ### Structuring in doubly linked list

# %% [markdown]
# ![Screenshot_2021-07-22-17-31-34-338_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-22-17-31-34-338_com.google.android.youtube.jpg)

# %% [markdown]
# #### Methods of doubly linked list![Screenshot_2021-07-22-17-34-17-613_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-22-17-34-17-613_com.google.android.youtube.jpg)

# %% [markdown]
# ### Time complexity for doubly linked list
#
# It will be same as linked list
# - Accessing: O(n)
# - Searching: O(n)
# - Inserting: O(n) or O(1)
# - Deleting: O(n) or O(1)

# %% [markdown]
# #### Implementation of doubly linked list in python

# %%
class Node(object):
    def __init__(self,prev=None,data=None,nxt=None):
        self.prev=prev
        self.data=data
        self.nxt=nxt
    def add_head(self,data):
        self.head=None
        node=Node(data,self.head)
        if self.head is None:
            print("Doubly linked list is empty")
            return

# %% [markdown]
# ##### Examples of doubly linked list
#
# ![Screenshot_2021-07-22-18-08-37-241_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-22-18-08-37-241_com.google.android.youtube.jpg)
