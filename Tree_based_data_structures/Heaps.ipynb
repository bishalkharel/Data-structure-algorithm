# %% [markdown]
# ## Heaps:
#
#
# ![Screenshot_2021-07-24-13-22-18-933_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-22-18-933_com.google.android.youtube.jpg)

# %% [markdown]
# ### Types of heaps
#
# - Min heaps
# - Max heaps

# %% [markdown]
# ### 1. Min heaps
# ![Screenshot_2021-07-24-13-28-31-782_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-28-31-782_com.google.android.youtube.jpg)

# %% [markdown]
# ### 2. Max heaps![Screenshot_2021-07-24-13-32-48-222_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-32-48-222_com.google.android.youtube.jpg)

# %% [markdown]
# ### How to delete nodes (parent node from heaps)

# %% [markdown]
# ![Screenshot_2021-07-24-13-39-28-532_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-39-28-532_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-13-48-39-219_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-48-39-219_com.google.android.youtube.jpg)
