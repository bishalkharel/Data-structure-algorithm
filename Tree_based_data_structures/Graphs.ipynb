# %% [markdown]
# ## Graphs: graphs are tree based dsa

# %% [markdown]
# ![Screenshot_2021-07-24-14-17-10-957_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-17-10-957_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-14-17-12-520_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-17-12-520_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-14-34-52-948_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-34-52-948_com.google.android.youtube.jpg)

# %% [markdown]
# The above set indicate the relation between two noes and below set indicates the edge between two nodes

# %% [markdown]
# #### Types of graphs
# - undirected graphs
# - Directed graphs

# %% [markdown]
# ### 1. Undirected graphs
# ![Screenshot_2021-07-24-14-54-39-773_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-54-39-773_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-14-55-58-817_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-55-58-817_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-14-58-04-694_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-14-58-04-694_com.google.android.youtube.jpg)
