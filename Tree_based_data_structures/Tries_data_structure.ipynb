# %% [markdown]
# ## Tries Data Structure

# %% [markdown]
# <b> We know that applying restrictions to tree can be super useful beacuse it makes our searching process super fast</b>

# %% [markdown]
# ![Screenshot_2021-07-24-13-09-38-224_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-09-38-224_com.google.android.youtube.jpg)

# %% [markdown]
# ![Screenshot_2021-07-24-13-15-01-255_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-24-13-15-01-255_com.google.android.youtube.jpg)

# %% [markdown]
# <b> Trie data structure works by making a possible words from each letter </b>
