# %% [markdown]
# ### Binary search tree is a type of tree data structure which have certain limitations which are mentioned below

# %% [markdown]
# ![Screenshot_2021-07-23-17-30-00-389_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-23-17-30-00-389_com.google.android.youtube.jpg)
