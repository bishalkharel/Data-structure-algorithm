# %% [markdown]
# \begin{equation}
# O(logn)
# \end{equation}
#
# #### As you can see when changing the value of x the y sky rockets but after certain values it doesnt change like before

# %%
import matplotlib.pyplot as plt
import numpy as np

a=np.arange(0,700,0.1)
b=np.log(a)
plt.plot(a,b)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %% [markdown]
# \begin{equation}
# O(n)
# \end{equation}
#
#   #### This equation tells us that the amount of opeations is directly propotional to amount of dataset given
#   #### so our graph is linear

# %%
x=np.arange(0,10,1)
y=np.arange(0,10,1)
plt.plot(x,y)
plt.show()

# %% [markdown]
# \begin{equation}
# O(nlogn)
# \end{equation}
# ###     This is possibly the bad equation because see the following graph.

# %%
x=np.arange(0,10,0.1)
y=x*np.log(x)
plt.plot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %% [markdown]
# \begin{equation}
#  O(2^n)  \quad  O(n^2)
# \end{equation}
#
# ### This metric is considered as really bad because as you can see in the graph the equations are exponential and polynomial

# %%
# for eqation 1

x=np.arange(10,100,1)
y=2^x
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Important terms:
# #### - Parallel array:
# #####       Parallel arrays are those arrays which have same length and relative values
#
# ### Attributes of array
# #### . Name (name of your array e.g: a=[1,2,3]
# #### . Size
# #### . Type of array

# %% [markdown]
# ![Screenshot_2021-07-16-13-54-19-842_com.google.android.youtube.jpg](attachment:Screenshot_2021-07-16-13-54-19-842_com.google.android.youtube.jpg)

# %% [markdown]
# #### We saw that array size cannot be changed once initialized but we can change the size in  <i><font color="red" size=4px> ArrayList</font></i> . This is the thing that we use in python...remember you can change the size of list even after initialized

# %% [markdown]
# <underline><p> In python there is no such thing called Array and ArrayList but we do have <i>List</i> which is the combination of array and arraylist which is quite a lot of complex data structure</p></underline>

# %%
a=[1,2,3,' ','   ']
len(a[4])
# Out:
# 3

# %% [markdown]
# <b> As you can see above there is actual object in 4th index but it will count no.of white spaces in 4th index and give us a result there. In our case it gave us 3 because we have 3 white spaces in 4th index</b>

# %%
a=[1,2,3,4,5,6,7]
a.insert(4,3)
a
# Out:
# [1, 2, 3, 4, 3, 5, 6, 7]

# %% [markdown]
# <b> You can add element just like an arraylist in pythons list by insert() method which takes two arguments first argument takes index of list and second argument takes the object you want to add. For example:</b> <font color="green"><p>a.insert(4,3)</p></font>
